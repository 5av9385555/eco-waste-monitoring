# %% [markdown]
# # Evaluate pretrained waste classifier on TrashNet
#
# This notebook mirrors `python -m src.evaluate` but lets you explore results interactively.

# %%
# !pip -q install -r ../requirements.txt

# %%
# !python -m src.download_data

# %%
# !python -m src.evaluate

# %% [markdown]
# Open `reports/classification_report.txt` and `reports/confusion_matrix.png` to view metrics.
